# %%
import sys
import os

current_dir = os.getcwd()

parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.append(parent_dir)

from playlist_etl.utils import *
from playlist_etl.transform import *
from playlist_etl.extract import *
from playlist_etl.view_count import *
from playlist_etl.mongo_db_client import *
from playlist_etl.config import *
from playlist_etl.transform2 import *

set_secrets()
# Out:
# 11-19 16:02:24 - INFO - set_secrets() - env_path/Users/eli/github/tunemeld/.env.dev

# %%
class Aggregate:
    def __init__(self, mongo_client):
        self.mongo_client = mongo_client
        
    def aggregate(self, track_playlist):
        candidates_by_genre = self._group_by_genre(track_playlist)
        aggregate_by_isrc = self._group_by_isrc_within_genre(candidates_by_genre)
        matches = self._get_matches(aggregate_by_isrc)
        self._rank_matches(matches)

    def _group_by_genre(self, track_playlist) -> dict:
        """Group ISRC matches across the same genre from different services.
        Eg. output
        {
            "dance": {
                "23490580": {
                    "rank": 1,
                    "service_name": "soundcloud"
                },
                "23490580": {
                    "rank": 2,
                    "service_name": "spotify"
                }
            }
        }
        """
        candidates_by_genre = defaultdict(dict)
        for genre_name in GENRE_NAMES:
            for service_name in SERVICE_NAMES:
                track_playlist = self.track_playlist_collection.find({"service_name": service_name, "genre_name": genre_name})
                for track in track_playlist["tracks"]:
                    candidates_by_genre[genre_name][track["isrc"]] = {
                        "rank": track["rank"],
                        "service_name": service_name,
                    }
        return candidates_by_genre

    def _group_by_isrc_within_genre(self, candidate_by_genre):
        """Groups ISRC matches across the same genre. Two different playlists can have the same ISRC.
        Eg. output
        {
            "dance": {
                "23490580": {
                    [("soundcloud", 1)]
                },
                "23434580": {
                    [("soundcloud", 1), ("spotify", 2)]
                }
            }
            "pop": {
                "23490523": {
                    [("soundcloud", 1), ("spotify", 2)]
                },
                "23490580": {
                    [("soundcloud", 1)]
                }
        }
        """
        aggregate_by_isrc = defaultdict(lambda: defaultdict(list))
        for genre, candidates in candidate_by_genre.items():
            for isrc, candidate in candidates.items():
                aggregate_by_isrc[genre][isrc].append(
                    (candidate["service_name"], candidate["rank"])
                )
        return aggregate_by_isrc

    def _get_matches(self, aggregate_by_isrc):
        """Get ISRCs that come up more than once for the same genre.
        Eg. input
         {
            "pop": {
                "23490523": {
                    [("soundcloud", 1), ("spotify", 2)]
                },
                "23490580": {
                    [("soundcloud", 1)]
                }
        }
        Eg. output:
        {
            "pop": {
                "23490523": {
                    [("soundcloud", 1), ("spotify", 2)]
        }
        """
        matches = {}
        for genre, isrcs in aggregate_by_isrc.items():
            matches[genre] = {isrc: sources for isrc, sources in isrcs.items() if len(sources) > 1}
        return matches

    def _rank_matches(self, matches):
        """Rank matches based on the rank of the services.
        Eg. input
        {
            "pop": {
                "23490523": {
                    [("soundcloud", 1), ("spotify", 2)]
                },
        }
        Eg. output
        {
            "dance": {
                1: {
                    ISRC: "23490523",
                    sources: [("soundcloud", 1), ("spotify", 2)]
                }
            }
        }
        """
        rank_priority = ["AppleMusic", "SoundCloud", "Spotify"]
        for genre_name, matches_by_genre in matches.items():
            for isrc, sources in matches_by_genre.items():
                ranked_sources = sorted(sources, key=lambda x: rank_priority.index(x[0]))
                matches[genre_name][isrc] = {"isrc": isrc, "sources": ranked_sources}

        return matches

# %%
aggregate = Aggregate(MongoDBClient())
a, b = aggregate._get_track_data_from_mongo()
# Out:
# 11-19 16:16:35 - INFO - set_secrets() - env_path/Users/eli/github/tunemeld/.env.dev

# %%
aggregate = Aggregate(mongo_client)
aggregate.aggregate()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 aggregate = Aggregate(mongo_client)
# ----> 2 aggregate.aggregate()
#
# File ~/github/tunemeld/playlist_etl/transform2.py:294, in Aggregate.aggregate(self)
#     293 def aggregate(self):
# --> 294     tracks, track_playlist = self._get_track_data_from_mongo()
#     295     self._aggregate_tracks_by_isrc(track_playlist)
#
# File ~/github/tunemeld/playlist_etl/transform2.py:304, in Aggregate._get_track_data_from_mongo(self)
#     303 def _get_track_data_from_mongo(self):
# --> 304     tracks = self.mongo_client.read_data(TRACK_COLLECTION)
#     305     track_playlist = self.mongo_client.read_data(TRACK_PLAYLIST_COLLECTION)
#     306     return tracks, track_playlist
#
# TypeError: 'Database' object is not callable

# %%
mongo_client.read_data(TRACK_PLAYLIST_COLLECTION)
# Out:
# [{'_id': ObjectId('673bd1cf7fc0f4ca6df0f081'),
#   'key': 'AppleMusic_country',
#   'value': [{'isrc': 'US6XF2400213', 'rank': 1},
#    {'isrc': 'USUM72408405', 'rank': 2},
#    {'isrc': 'USUG12406387', 'rank': 3},
#    {'isrc': 'USUM72405599', 'rank': 4},
#    {'isrc': 'QMRSZ2400822', 'rank': 5},
#    {'isrc': 'USUYG1580113', 'rank': 6},
#    {'isrc': 'QM24S2401097', 'rank': 7},
#    {'isrc': 'QMDA62488992', 'rank': 8},
#    {'isrc': 'USUM72410290', 'rank': 9},
#    {'isrc': 'QMCQK1900370', 'rank': 10},
#    {'isrc': 'USSM12403681', 'rank': 11},
#    {'isrc': 'USRN12400011', 'rank': 12},
#    {'isrc': 'QZRD92405271', 'rank': 13},
#    {'isrc': 'USAN20000251', 'rank': 14},
#    {'isrc': 'USUG12405562', 'rank': 15},
#    {'isrc': 'USRN12300107', 'rank': 16},
#    {'isrc': 'USAT22402805', 'rank': 17},
#    {'isrc': 'USUG12404551', 'rank': 18},
#    {'isrc': 'USWB12403709', 'rank': 19},
#    {'isrc': 'USWB12402402', 'rank': 20},
#    {'isrc': 'USAT22408980', 'rank': 21},
#    {'isrc': 'USWB12404018', 'rank': 22},
#    {'isrc': 'QMRSZ2401388', 'rank': 23},
#    {'isrc': 'QZZVQ2400059', 'rank': 24},
#    {'isrc': 'USQX92402558', 'rank': 25},
#    {'isrc': 'USUM72401036', 'rank': 26},
#    {'isrc': 'USUM72405595', 'rank': 27},
#    {'isrc': 'USQX92401733', 'rank': 28},
#    {'isrc': 'USWB12404997', 'rank': 29},
#    {'isrc': 'QZRD92405544', 'rank': 30},
#    {'isrc': 'USQX92403221', 'rank': 31},
#    {'isrc': 'AUXN22451684', 'rank': 32},
#    {'isrc': 'QZWH32400054', 'rank': 33},
#    {'isrc': 'USQX92400800', 'rank': 34},
#    {'isrc': 'QMCQK1900367', 'rank': 35},
#    {'isrc': 'USUG12300827', 'rank': 36},
#    {'isrc': 'QZRD92405772', 'rank': 37},
#    {'isrc': 'USQX92404450', 'rank': 38},
#    {'isrc': 'USUG12309787', 'rank': 39},
#    {'isrc': 'QZWH32400344', 'rank': 40},
#    {'isrc': 'USWB12400492', 'rank': 41},
#    {'isrc': 'USANG2424929', 'rank': 42},
#    {'isrc': 'QMRSZ2301468', 'rank': 43},
#    {'isrc': 'USAT22403721', 'rank': 44},
#    {'isrc': 'QZWH32400055', 'rank': 45},
#    {'isrc': 'USUG12405957', 'rank': 46},
#    {'isrc': 'USWB12402131', 'rank': 47},
#    {'isrc': 'US6XF2400120', 'rank': 48},
#    {'isrc': 'QZZ222400014', 'rank': 49},
#    {'isrc': 'QZYG82300092', 'rank': 50},
#    {'isrc': 'QZEQU2401970', 'rank': 51},
#    {'isrc': 'USRN12400018', 'rank': 52},
#    {'isrc': 'USUM72409932', 'rank': 53},
#    {'isrc': 'USQX92401667', 'rank': 54},
#    {'isrc': 'USUG12404541', 'rank': 55},
#    {'isrc': 'QZZVQ2400170', 'rank': 56},
#    {'isrc': 'QZRD92405687', 'rank': 57},
#    {'isrc': 'USUG12404146', 'rank': 58},
#    {'isrc': 'USWB12307026', 'rank': 59},
#    {'isrc': 'QZWH32400133', 'rank': 60},
#    {'isrc': 'QZRD92405285', 'rank': 61},
#    {'isrc': 'QZRD92404862', 'rank': 62},
#    {'isrc': 'US6XF2400148', 'rank': 63},
#    {'isrc': 'USUG12404015', 'rank': 64},
#    {'isrc': 'QZRD92404651', 'rank': 65},
#    {'isrc': 'USUG12402096', 'rank': 66},
#    {'isrc': 'QZRD92405609', 'rank': 67},
#    {'isrc': 'USWB12402334', 'rank': 68},
#    {'isrc': 'USWB12400044', 'rank': 69},
#    {'isrc': 'USUM72404990', 'rank': 70},
#    {'isrc': 'USQX92306497', 'rank': 71},
#    {'isrc': 'QMRSZ2400815', 'rank': 72},
#    {'isrc': 'USUG12403356', 'rank': 73},
#    {'isrc': 'QMRSZ2400516', 'rank': 74},
#    {'isrc': 'USUM72308079', 'rank': 75}]},
#  {'_id': ObjectId('673bd1cf7fc0f4ca6df0f082'),
#   'key': 'AppleMusic_dance',
#   'value': [{'isrc': 'GBCFB2401282', 'rank': 1},
#    {'isrc': 'DECE72401347', 'rank': 2},
#    {'isrc': 'NLRD52350359', 'rank': 3},
#    {'isrc': 'GBUM72405917', 'rank': 4},
#    {'isrc': 'US38Y2418589', 'rank': 5},
#    {'isrc': 'GBUM72406618', 'rank': 6},
#    {'isrc': 'US38Y2414974', 'rank': 7},
#    {'isrc': 'DEEC33501508', 'rank': 8},
#    {'isrc': 'USUG12405610', 'rank': 9},
#    {'isrc': 'NL8RL2440716', 'rank': 10},
#    {'isrc': 'GBUM72402265', 'rank': 11},
#    {'isrc': 'GB45A2400175', 'rank': 12},
#    {'isrc': 'DEE862401825', 'rank': 13},
#    {'isrc': 'DEA622403098', 'rank': 14},
#    {'isrc': 'GBCEN2400129', 'rank': 15},
#    {'isrc': 'GBCPZ2423721', 'rank': 16},
#    {'isrc': 'GBEWA2404850', 'rank': 17},
#    {'isrc': 'US38Y2417571', 'rank': 18},
#    {'isrc': 'US38Y2425861', 'rank': 19},
#    {'isrc': 'NL8RL2446320', 'rank': 20},
#    {'isrc': 'QZUCN2201775', 'rank': 21},
#    {'isrc': 'QMDA62467328', 'rank': 22},
#    {'isrc': 'GBUM72406388', 'rank': 23},
#    {'isrc': 'USUG12405928', 'rank': 24},
#    {'isrc': 'GBCFB2400830', 'rank': 25},
#    {'isrc': 'USUG12405837', 'rank': 26},
#    {'isrc': 'GBUM72404466', 'rank': 27},
#    {'isrc': 'NLZ542400735', 'rank': 28},
#    {'isrc': 'USQX92403689', 'rank': 29},
#    {'isrc': 'US23A1584731', 'rank': 30},
#    {'isrc': 'GBUM72402617', 'rank': 31},
#    {'isrc': 'NL8RL2429546', 'rank': 32},
#    {'isrc': 'USUG12403371', 'rank': 33},
#    {'isrc': 'GBCFB2400824', 'rank': 34},
#    {'isrc': 'USUG12402628', 'rank': 35},
#    {'isrc': 'GBARL2400737', 'rank': 36},
#    {'isrc': 'GBCEN2400185', 'rank': 37},
#    {'isrc': 'AUFF02400052', 'rank': 38},
#    {'isrc': 'USA2P2430008', 'rank': 39},
#    {'isrc': 'USUG12401003', 'rank': 40},
#    {'isrc': 'GBEWA2404420', 'rank': 41},
#    {'isrc': 'GBUM72403961', 'rank': 42},
#    {'isrc': 'GBCFB2400907', 'rank': 43},
#    {'isrc': 'GB5KW2402411', 'rank': 44},
#    {'isrc': 'NLF712408077', 'rank': 45},
#    {'isrc': 'USAR12400253', 'rank': 46},
#    {'isrc': 'GBARL2401535', 'rank': 47},
#    {'isrc': 'GB45A2400214', 'rank': 48},
#    {'isrc': 'USUG12405639', 'rank': 49},
#    {'isrc': 'QMDA62455623', 'rank': 50},
#    {'isrc': 'GBUR62000909', 'rank': 51},
#    {'isrc': 'USRE12400414', 'rank': 52},
#    {'isrc': 'GBCEN2400181', 'rank': 53},
#    {'isrc': 'USQX92404437', 'rank': 54},
#    {'isrc': 'DEE862401827', 'rank': 55},
#    {'isrc': 'GBCFB2400726', 'rank': 56},
#    {'isrc': 'GBCFB2400964', 'rank': 57},
#    {'isrc': 'USRE12400413', 'rank': 58},
#    {'isrc': 'US38Y2411868', 'rank': 59},
#    {'isrc': 'USRE12400467', 'rank': 60},
#    {'isrc': 'GBUM72405427', 'rank': 61},
#    {'isrc': 'GBCPZ2423810', 'rank': 62},
#    {'isrc': 'GBCPZ2423765', 'rank': 63},
#    {'isrc': 'GBARL2400999', 'rank': 64},
#    {'isrc': 'NL8RL2434871', 'rank': 65},
#    {'isrc': 'GBCFB2400756', 'rank': 66},
#    {'isrc': 'UK7MC2400052', 'rank': 67},
#    {'isrc': 'GBARL2401413', 'rank': 68},
#    {'isrc': 'GBAHS2400522', 'rank': 69},
#    {'isrc': 'GBKQU2489111', 'rank': 70},
#    {'isrc': 'GBEWA2403591', 'rank': 71},
#    {'isrc': 'US23A1586842', 'rank': 72},
#    {'isrc': 'GBCFB2400721', 'rank': 73},
#    {'isrc': 'UKFTL1600320', 'rank': 74},
#    {'isrc': 'USUG12406149', 'rank': 75},
#    {'isrc': 'USQE92400285', 'rank': 76},
#    {'isrc': 'NL8RL2443738', 'rank': 77},
#    {'isrc': 'DEEC33501671', 'rank': 78},
#    {'isrc': 'USQX92401650', 'rank': 79},
#    {'isrc': 'USA2P2446028', 'rank': 80},
#    {'isrc': 'FRX762422912', 'rank': 81},
#    {'isrc': 'GBK6Y2424101', 'rank': 82},
#    {'isrc': 'GBPQS2400350', 'rank': 83},
#    {'isrc': 'FRD9M2404090', 'rank': 84},
#    {'isrc': 'GBEWA2404970', 'rank': 85},
#    {'isrc': 'NLF712408117', 'rank': 86},
#    {'isrc': 'QZUCN2201990', 'rank': 87},
#    {'isrc': 'USA2P2465995', 'rank': 88},
#    {'isrc': 'QMDA62401355', 'rank': 89},
#    {'isrc': 'USUS12400702', 'rank': 90},
#    {'isrc': 'QMDA72417785', 'rank': 91},
#    {'isrc': 'USAT22408934', 'rank': 92},
#    {'isrc': 'GBCPZ2423950', 'rank': 93},
#    {'isrc': 'GBAHS2400513', 'rank': 94},
#    {'isrc': 'AUCN32400171', 'rank': 95},
#    {'isrc': 'GB45A2400212', 'rank': 96},
#    {'isrc': 'GBJAJ2401432', 'rank': 97},
#    {'isrc': 'GBEFR2309266', 'rank': 98},
#    {'isrc': 'NLF712406539', 'rank': 99},
#    {'isrc': 'CA6D22400668', 'rank': 100}]},
#  {'_id': ObjectId('673bd1cf7fc0f4ca6df0f083'),
#   'key': 'AppleMusic_pop',
#   'value': [{'isrc': 'USRC12403001', 'rank': 1},
#    {'isrc': 'USUG12406903', 'rank': 2},
#    {'isrc': 'GBARL2401376', 'rank': 3},
#    {'isrc': 'USUM72403305', 'rank': 4},
#    {'isrc': 'USWB12403749', 'rank': 5},
#    {'isrc': 'USAT22409172', 'rank': 6},
#    {'isrc': 'USUM72404100', 'rank': 7},
#    {'isrc': 'GBARL2400510', 'rank': 8},
#    {'isrc': 'USRC12402692', 'rank': 9},
#    {'isrc': 'USWB12302870', 'rank': 10},
#    {'isrc': 'USUM72408549', 'rank': 11},
#    {'isrc': 'USUM72407015', 'rank': 12},
#    {'isrc': 'USAT22401341', 'rank': 13},
#    {'isrc': 'USUM72401994', 'rank': 14},
#    {'isrc': 'USUG12401967', 'rank': 15},
#    {'isrc': 'HKJ962415408', 'rank': 16},
#    {'isrc': 'USWB12400913', 'rank': 17},
#    {'isrc': 'USUM72404101', 'rank': 18},
#    {'isrc': 'USSM12405453', 'rank': 19},
#    {'isrc': 'USSM12406242', 'rank': 20},
#    {'isrc': 'USUG12401775', 'rank': 21},
#    {'isrc': 'USWB12302315', 'rank': 22},
#    {'isrc': 'USAT22401350', 'rank': 23},
#    {'isrc': 'USUM72404990', 'rank': 24},
#    {'isrc': 'USUG12406331', 'rank': 25},
#    {'isrc': 'USRC12402208', 'rank': 26},
#    {'isrc': 'ARQIW2404204', 'rank': 27},
#    {'isrc': 'USWB12307016', 'rank': 28},
#    {'isrc': 'USUG12401766', 'rank': 29},
#    {'isrc': 'GBUM72400322', 'rank': 30},
#    {'isrc': 'USAT22408615', 'rank': 31},
#    {'isrc': 'USQX92405464', 'rank': 32},
#    {'isrc': 'USSM12405456', 'rank': 33},
#    {'isrc': 'GBAYE2400888', 'rank': 34},
#    {'isrc': 'QZJ842400387', 'rank': 35},
#    {'isrc': 'QZTB92360479', 'rank': 36},
#    {'isrc': 'USWB12400001', 'rank': 37},
#    {'isrc': 'USAT22001300', 'rank': 38},
#    {'isrc': 'USSM12401865', 'rank': 39},
#    {'isrc': 'QMDA62229905', 'rank': 40},
#    {'isrc': 'USSM12402296', 'rank': 41},
#    {'isrc': 'USUM72409273', 'rank': 42},
#    {'isrc': 'USWB12402947', 'rank': 43},
#    {'isrc': 'USUM72409654', 'rank': 44},
#    {'isrc': 'USSM12405549', 'rank': 45},
#    {'isrc': 'USAT22406164', 'rank': 46},
#    {'isrc': 'USHM92438095', 'rank': 47},
#    {'isrc': 'UKWLG2400013', 'rank': 48},
#    {'isrc': 'QZZVQ2400059', 'rank': 49},
#    {'isrc': 'USUM72407248', 'rank': 50},
#    {'isrc': 'USAT22407542', 'rank': 51},
#    {'isrc': 'USUM72401993', 'rank': 52},
#    {'isrc': 'USUM72212470', 'rank': 53},
#    {'isrc': 'GBAHT2400223', 'rank': 54},
#    {'isrc': 'USSM12407199', 'rank': 55},
#    {'isrc': 'USRC12402958', 'rank': 56},
#    {'isrc': 'USSM12407085', 'rank': 57},
#    {'isrc': 'USWB12402105', 'rank': 58},
#    {'isrc': 'QZTTB2400005', 'rank': 59},
#    {'isrc': 'USUG12305911', 'rank': 60},
#    {'isrc': 'GBARL2401092', 'rank': 61},
#    {'isrc': 'USUG12401028', 'rank': 62},
#    {'isrc': 'USA2P2439683', 'rank': 63},
#    {'isrc': 'USSM12405448', 'rank': 64},
#    {'isrc': 'USUG12405674', 'rank': 65},
#    {'isrc': 'USUG12401040', 'rank': 66},
#    {'isrc': 'USRC12400764', 'rank': 67},
#    {'isrc': 'USRC12402690', 'rank': 68},
#    {'isrc': 'USWB12403060', 'rank': 69},
#    {'isrc': 'GBUM72401610', 'rank': 70}]},
#  {'_id': ObjectId('673bd1cf7fc0f4ca6df0f084'),
#   'key': 'AppleMusic_rap',
#   'value': [{'isrc': 'USUG12404790', 'rank': 1},
#    {'isrc': 'USAT22409580', 'rank': 2},
#    {'isrc': 'USSM12408346', 'rank': 3},
#    {'isrc': 'USUG12405324', 'rank': 4},
#    {'isrc': 'USUG12404787', 'rank': 5},
#    {'isrc': 'USSM12406727', 'rank': 6},
#    {'isrc': 'USAT22403437', 'rank': 7},
#    {'isrc': 'QZNMV2493141', 'rank': 8},
#    {'isrc': 'USUG12407725', 'rank': 9},
#    {'isrc': 'USSM12404181', 'rank': 10},
#    {'isrc': 'USSM12406728', 'rank': 11},
#    {'isrc': 'USAT22403439', 'rank': 12},
#    {'isrc': 'USSM12402037', 'rank': 13},
#    {'isrc': 'QZNMW2477249', 'rank': 14},
#    {'isrc': 'USUG12405322', 'rank': 15},
#    {'isrc': 'QZNMX2391413', 'rank': 16},
#    {'isrc': 'USQX92405793', 'rank': 17},
#    {'isrc': 'USSM12406726', 'rank': 18},
#    {'isrc': 'USUM72410710', 'rank': 19},
#    {'isrc': 'USUYG1542823', 'rank': 20},
#    {'isrc': 'USRC12403510', 'rank': 21},
#    {'isrc': 'USUM72411036', 'rank': 22},
#    {'isrc': 'USUG12404775', 'rank': 23},
#    {'isrc': 'USAT22409333', 'rank': 24},
#    {'isrc': 'QZNMZ2389200', 'rank': 25},
#    {'isrc': 'USUM72411203', 'rank': 26},
#    {'isrc': 'USSM12309176', 'rank': 27},
#    {'isrc': 'QZNMU2421699', 'rank': 28},
#    {'isrc': 'USSM12402034', 'rank': 29},
#    {'isrc': 'USUYG1549902', 'rank': 30},
#    {'isrc': 'USAT22409494', 'rank': 31},
#    {'isrc': 'USQX92405285', 'rank': 32},
#    {'isrc': 'USUM72404717', 'rank': 33},
#    {'isrc': 'USQX92402890', 'rank': 34},
#    {'isrc': 'USQX92405790', 'rank': 35},
#    {'isrc': 'USUG12207232', 'rank': 36},
#    {'isrc': 'USSM12406731', 'rank': 37},
#    {'isrc': 'USUYG1577731', 'rank': 38},
#    {'isrc': 'USUM72410275', 'rank': 39},
#    {'isrc': 'USAT22409336', 'rank': 40},
#    {'isrc': 'TCAIW2412832', 'rank': 41},
#    {'isrc': 'USAT22401724', 'rank': 42},
#    {'isrc': 'USUM72410255', 'rank': 43},
#    {'isrc': 'USUM72410963', 'rank': 44},
#    {'isrc': 'USUG12405317', 'rank': 45},
#    {'isrc': 'USUM72410597', 'rank': 46},
#    {'isrc': 'USAT22402999', 'rank': 47},
#    {'isrc': 'USUYG1574524', 'rank': 48},
#    {'isrc': 'USSM12403207', 'rank': 49},
#    {'isrc': 'USQX92403243', 'rank': 50},
#    {'isrc': 'USAT22403299', 'rank': 51},
#    {'isrc': 'USUG12202512', 'rank': 52},
#    {'isrc': 'USAT22409895', 'rank': 53},
#    {'isrc': 'QMDA62478846', 'rank': 54},
#    {'isrc': 'USSM12402033', 'rank': 55},
#    {'isrc': 'USQX92400857', 'rank': 56},
#    {'isrc': 'USUM72411009', 'rank': 57},
#    {'isrc': 'QMRSZ2401183', 'rank': 58},
#    {'isrc': 'USRC12400299', 'rank': 59},
#    {'isrc': 'USAT22306575', 'rank': 60},
#    {'isrc': 'USQX92405477', 'rank': 61},
#    {'isrc': 'USQX92404982', 'rank': 62},
#    {'isrc': 'USAT22409501', 'rank': 63},
#    {'isrc': 'QZS7J2442847', 'rank': 64},
#    {'isrc': 'USSM12402041', 'rank': 65},
#    {'isrc': 'USUG12406536', 'rank': 66},
#    {'isrc': 'USAT22409693', 'rank': 67},
#    {'isrc': 'USSM12403111', 'rank': 68},
#    {'isrc': 'USUG12407284', 'rank': 69},
#    {'isrc': 'USSM12407950', 'rank': 70},
#    {'isrc': 'USAT22409507', 'rank': 71},
#    {'isrc': 'USRC12402924', 'rank': 72},
#    {'isrc': 'USQX92402617', 'rank': 73},
#    {'isrc': 'CH7811114260', 'rank': 74},
#    {'isrc': 'USA2P2461078', 'rank': 75},
#    {'isrc': 'USSM12404354', 'rank': 76},
#    {'isrc': 'USAT22306571', 'rank': 77},
#    {'isrc': 'USUM72404114', 'rank': 78},
#    {'isrc': 'USUYG1551723', 'rank': 79},
#    {'isrc': 'USUM72411088', 'rank': 80},
#    {'isrc': 'TCAIY2427253', 'rank': 81},
#    {'isrc': 'USAT22408896', 'rank': 82},
#    {'isrc': 'USUYG1445224', 'rank': 83},
#    {'isrc': 'USSM12406730', 'rank': 84},
#    {'isrc': 'USQX92400087', 'rank': 85},
#    {'isrc': 'USAT22408149', 'rank': 86},
#    {'isrc': 'USUM72411015', 'rank': 87},
#    {'isrc': 'USAT22409116', 'rank': 88},
#    {'isrc': 'USQX92405225', 'rank': 89},
#    {'isrc': 'USUG12300079', 'rank': 90},
#    {'isrc': 'USUM72305623', 'rank': 91},
#    {'isrc': 'USUM72411103', 'rank': 92},
#    {'isrc': 'USUM72307927', 'rank': 93},
#    {'isrc': 'USUYG1390429', 'rank': 94},
#    {'isrc': 'USAT22409889', 'rank': 95},
#    {'isrc': 'USQX92405366', 'rank': 96},
#    {'isrc': 'USUM72409892', 'rank': 97},
#    {'isrc': 'USA2P2460384', 'rank': 98},
#    {'isrc': 'USWB12403878', 'rank': 99},
#    {'isrc': 'USUG12400910', 'rank': 100}]},
#  {'_id': ObjectId('673bd1cf7fc0f4ca6df0f085'),
#   'key': 'SoundCloud_country',
#   'value': [{'isrc': 'USUYG1580113', 'rank': 1},
#    {'isrc': 'QZRD92406327', 'rank': 2},
#    {'isrc': 'QMRSZ2401879', 'rank': 3},
#    {'isrc': 'US6XF2400215', 'rank': 4},
#    {'isrc': 'USUG12407849', 'rank': 5},
#    {'isrc': 'USAT22409827', 'rank': 6},
#    {'isrc': 'USWB12404651', 'rank': 7},
#    {'isrc': 'USWB12404613', 'rank': 8},
#    {'isrc': 'QMGVJ2400200', 'rank': 9},
#    {'isrc': 'USUG12404551', 'rank': 10},
#    {'isrc': 'QZYG82300097', 'rank': 11},
#    {'isrc': 'USQX92403072', 'rank': 12},
#    {'isrc': 'USWB12404670', 'rank': 13},
#    {'isrc': 'QMDA72409773', 'rank': 14},
#    {'isrc': 'USUG12405957', 'rank': 15},
#    {'isrc': 'USWB12404660', 'rank': 16},
#    {'isrc': 'QMDA72442242', 'rank': 17},
#    {'isrc': 'QZEQU2402236', 'rank': 18},
#    {'isrc': 'USSM12403680', 'rank': 19},
#    {'isrc': 'USWB12403821', 'rank': 20},
#    {'isrc': 'USWB12404997', 'rank': 21},
#    {'isrc': 'USWB12404612', 'rank': 22},
#    {'isrc': 'USUM72410290', 'rank': 23},
#    {'isrc': 'USWB12404993', 'rank': 24},
#    {'isrc': 'QZRD92405764', 'rank': 25},
#    {'isrc': 'QZS7J2416622', 'rank': 26},
#    {'isrc': 'USWB12403711', 'rank': 27},
#    {'isrc': 'QM24S2406875', 'rank': 28},
#    {'isrc': 'USWB12403320', 'rank': 29},
#    {'isrc': 'USWB12404406', 'rank': 30},
#    {'isrc': 'USAT22409395', 'rank': 31},
#    {'isrc': 'QZRD92405763', 'rank': 32},
#    {'isrc': 'QZEQU2402275', 'rank': 33},
#    {'isrc': 'USUG12406106', 'rank': 34},
#    {'isrc': 'USUG12406387', 'rank': 35},
#    {'isrc': 'QZZ8A2464113', 'rank': 36},
#    {'isrc': 'USWB12404992', 'rank': 37},
#    {'isrc': 'QMCQK1900361', 'rank': 38},
#    {'isrc': 'USWB12403904', 'rank': 39},
#    {'isrc': 'USQX92404937', 'rank': 40},
#    {'isrc': 'USUM72412368', 'rank': 41},
#    {'isrc': 'USA2P2462495', 'rank': 42},
#    {'isrc': 'QMRSZ2401486', 'rank': 43},
#    {'isrc': 'USUG12406400', 'rank': 44},
#    {'isrc': 'USAT22408980', 'rank': 45},
#    {'isrc': 'USUG12406865', 'rank': 46},
#    {'isrc': 'QMCQK1900363', 'rank': 47},
#    {'isrc': 'USWB12404011', 'rank': 48},
#    {'isrc': 'USWB12404018', 'rank': 49},
#    {'isrc': 'USWB12403744', 'rank': 50}]},
#  {'_id': ObjectId('673bd1cf7fc0f4ca6df0f086'),
#   'key': 'SoundCloud_dance',
#   'value': [{'isrc': 'GBKQU2497621', 'rank': 1},
#    {'isrc': 'QZTGW2401725', 'rank': 2},
#    {'isrc': 'CBEFB2400039', 'rank': 3},
#    {'isrc': 'GBUM72406618', 'rank': 4},
#    {'isrc': 'USUS12400773', 'rank': 5},
#    {'isrc': 'USUYG1578379', 'rank': 6},
#    {'isrc': 'USA2P2466341', 'rank': 7},
#    {'isrc': 'US38Y2425861', 'rank': 8},
#    {'isrc': 'USZ4V2400354', 'rank': 9},
#    {'isrc': 'USAR12400155', 'rank': 10},
#    {'isrc': 'GBUM72406388', 'rank': 11},
#    {'isrc': 'GBCFB2401282', 'rank': 12},
#    {'isrc': 'USA2P2463751', 'rank': 13},
#    {'isrc': 'CA5KR2501838', 'rank': 14},
#    {'isrc': 'GBCEN2400225', 'rank': 15},
#    {'isrc': 'GBCEN2400236', 'rank': 16},
#    {'isrc': 'QZSYP2442132', 'rank': 17},
#    {'isrc': 'GBTDG1302865', 'rank': 18},
#    {'isrc': 'QZTGW2401482', 'rank': 19},
#    {'isrc': 'GBAHS2400675', 'rank': 20},
#    {'isrc': 'USAT22409686', 'rank': 21},
#    {'isrc': 'US38Y2426350', 'rank': 22},
#    {'isrc': 'NLZ542400735', 'rank': 23},
#    {'isrc': 'GBCFB2401217', 'rank': 24},
#    {'isrc': 'QM24S2406675', 'rank': 25},
#    {'isrc': 'USA2P2464394', 'rank': 26},
#    {'isrc': 'USANG2465150', 'rank': 27},
#    {'isrc': 'GBEWA2405651', 'rank': 28},
#    {'isrc': 'QMDA62443078', 'rank': 29},
#    {'isrc': 'USUYG1579739', 'rank': 30},
#    {'isrc': 'GBUM72406694', 'rank': 31},
#    {'isrc': 'USUS12400768', 'rank': 32},
#    {'isrc': 'QZTGW2401354', 'rank': 33},
#    {'isrc': 'QZTGW2400848', 'rank': 34},
#    {'isrc': 'USA2P2446028', 'rank': 35},
#    {'isrc': 'USZ4V2400250', 'rank': 36},
#    {'isrc': 'NLT2H2401047', 'rank': 37},
#    {'isrc': 'USBBR2400027', 'rank': 38},
#    {'isrc': 'GBJX32475040', 'rank': 39},
#    {'isrc': 'GBJAJ2401425', 'rank': 40},
#    {'isrc': 'QM24S2406482', 'rank': 41},
#    {'isrc': 'GB5KW2402411', 'rank': 42},
#    {'isrc': 'AUFF02400196', 'rank': 43},
#    {'isrc': 'US38Y2422906', 'rank': 44},
#    {'isrc': 'QMDA72417785', 'rank': 45},
#    {'isrc': 'GBHAD2400076', 'rank': 46},
#    {'isrc': 'DK4YA2400388', 'rank': 47},
#    {'isrc': 'QM42K2448707', 'rank': 48},
#    {'isrc': 'QZS7J2422298', 'rank': 49},
#    {'isrc': 'USA2P2465010', 'rank': 50}]},
#  {'_id': ObjectId('673bd1cf7fc0f4ca6df0f087'),
#   'key': 'SoundCloud_pop',
#   'value': [{'isrc': 'USWB12404815', 'rank': 1},
#    {'isrc': 'USUM72408549', 'rank': 2},
#    {'isrc': 'USUM72408165', 'rank': 3},
#    {'isrc': 'KRA302400341', 'rank': 4},
#    {'isrc': 'USAT22408573', 'rank': 5},
#    {'isrc': 'USUG12404539', 'rank': 6},
#    {'isrc': 'QZTL92421924', 'rank': 7},
#    {'isrc': 'USSM12408937', 'rank': 8},
#    {'isrc': 'USSM12407085', 'rank': 9},
#    {'isrc': 'USRC12403153', 'rank': 10},
#    {'isrc': 'GB5KW2401289', 'rank': 11},
#    {'isrc': 'USAT22407542', 'rank': 12},
#    {'isrc': 'US38Y2416986', 'rank': 13},
#    {'isrc': 'USUM72404100', 'rank': 14},
#    {'isrc': 'US38Y2422296', 'rank': 15},
#    {'isrc': 'USAT22406808', 'rank': 16},
#    {'isrc': 'USUG12405631', 'rank': 17},
#    {'isrc': 'USSM12402821', 'rank': 18},
#    {'isrc': 'GB5KW2400732', 'rank': 19},
#    {'isrc': 'USA2P2449061', 'rank': 20},
#    {'isrc': 'USSM12402296', 'rank': 21},
#    {'isrc': 'USQX92404789', 'rank': 22},
#    {'isrc': 'USLD91757578', 'rank': 23},
#    {'isrc': 'USUM72401991', 'rank': 24},
#    {'isrc': 'USAT22401341', 'rank': 25},
#    {'isrc': 'USUM72404990', 'rank': 26},
#    {'isrc': 'GBAHT2400111', 'rank': 27},
#    {'isrc': 'QZTTB2400006', 'rank': 28},
#    {'isrc': 'QZZVQ2400059', 'rank': 29},
#    {'isrc': 'USQE92400082', 'rank': 30},
#    {'isrc': 'SEUM72401391', 'rank': 31},
#    {'isrc': 'QMJMT2405502', 'rank': 32},
#    {'isrc': 'USQX92401826', 'rank': 33},
#    {'isrc': 'USUM72413593', 'rank': 34},
#    {'isrc': 'USUG12400219', 'rank': 35},
#    {'isrc': 'USUM72400700', 'rank': 36},
#    {'isrc': 'QZES62336235', 'rank': 37},
#    {'isrc': 'USUM72401988', 'rank': 38},
#    {'isrc': 'USAT22403840', 'rank': 39},
#    {'isrc': 'USRC12402299', 'rank': 40},
#    {'isrc': 'USSM12403554', 'rank': 41},
#    {'isrc': 'USUM72317276', 'rank': 42},
#    {'isrc': 'USWB12403826', 'rank': 43},
#    {'isrc': 'USQE92400031', 'rank': 44},
#    {'isrc': 'USWB12307016', 'rank': 45},
#    {'isrc': 'USUM72401994', 'rank': 46},
#    {'isrc': 'GBAHT2301078', 'rank': 47},
#    {'isrc': 'USSM12307956', 'rank': 48},
#    {'isrc': 'USQX92307375', 'rank': 49},
#    {'isrc': 'USUM72400048', 'rank': 50}]},
#  {'_id': ObjectId('673bd1cf7fc0f4ca6df0f088'),
#   'key': 'SoundCloud_rap',
#   'value': [{'isrc': 'USAT22409333', 'rank': 1},
#    {'isrc': 'USUG12407725', 'rank': 2},
#    {'isrc': 'USUG12404790', 'rank': 3},
#    {'isrc': 'USUG12404786', 'rank': 4},
#    {'isrc': 'USC4R2446067', 'rank': 5},
#    {'isrc': 'USRC12403510', 'rank': 6},
#    {'isrc': 'USAT22409452', 'rank': 7},
#    {'isrc': 'USC4R2447759', 'rank': 8},
#    {'isrc': 'USLD91766523', 'rank': 9},
#    {'isrc': 'USUYG1580782', 'rank': 10},
#    {'isrc': 'USUYG1580730', 'rank': 11},
#    {'isrc': 'QMDA62418181', 'rank': 12},
#    {'isrc': 'QMRSZ2401721', 'rank': 13},
#    {'isrc': 'USUYG1583519', 'rank': 14},
#    {'isrc': 'QMDA62493286', 'rank': 15},
#    {'isrc': 'USUYG1583520', 'rank': 16},
#    {'isrc': 'USUYG1582235', 'rank': 17},
#    {'isrc': 'USUYG1581852', 'rank': 18},
#    {'isrc': 'USBWK2400099', 'rank': 19},
#    {'isrc': 'USUG12407997', 'rank': 20},
#    {'isrc': 'FRIDO2415322', 'rank': 21},
#    {'isrc': 'USSM12407950', 'rank': 22},
#    {'isrc': 'USRC12402920', 'rank': 23},
#    {'isrc': 'USUYG1578987', 'rank': 24},
#    {'isrc': 'USUYG1582108', 'rank': 25},
#    {'isrc': 'USAT22409336', 'rank': 26},
#    {'isrc': 'USA2P2464162', 'rank': 27},
#    {'isrc': 'CH7811114260', 'rank': 28},
#    {'isrc': 'QZS7J2404114', 'rank': 29},
#    {'isrc': 'USUYG1517939', 'rank': 30},
#    {'isrc': 'USUYG1579126', 'rank': 31},
#    {'isrc': 'USQX92405786', 'rank': 32},
#    {'isrc': 'USAT22409494', 'rank': 33},
#    {'isrc': 'USC4R2447762', 'rank': 34},
#    {'isrc': 'USUM72412737', 'rank': 35},
#    {'isrc': 'QMDA72421200', 'rank': 36},
#    {'isrc': 'USUG12407491', 'rank': 37},
#    {'isrc': 'USSM12408345', 'rank': 38},
#    {'isrc': 'USSM12408246', 'rank': 39},
#    {'isrc': 'QZNMW2440909', 'rank': 40},
#    {'isrc': 'QZJ842403650', 'rank': 41},
#    {'isrc': 'USUM72412018', 'rank': 42},
#    {'isrc': 'QMDA62478846', 'rank': 43},
#    {'isrc': 'USUYG1582102', 'rank': 44},
#    {'isrc': 'QMDA62418618', 'rank': 45},
#    {'isrc': 'USUYG1580733', 'rank': 46},
#    {'isrc': 'USLD91765979', 'rank': 47},
#    {'isrc': 'USAT22409446', 'rank': 48},
#    {'isrc': 'QZS7J2424505', 'rank': 49},
#    {'isrc': 'USA2P2464569', 'rank': 50}]},
#  {'_id': ObjectId('673bd1cf7fc0f4ca6df0f089'),
#   'key': 'Spotify_country',
#   'value': [{'isrc': 'USUYG1580113', 'rank': 1},
#    {'isrc': 'USUM72404990', 'rank': 2},
#    {'isrc': 'USQX92401667', 'rank': 3},
#    {'isrc': 'USUM72408405', 'rank': 4},
#    {'isrc': 'USAT22402805', 'rank': 5},
#    {'isrc': 'QZZVQ2400095', 'rank': 6},
#    {'isrc': 'USWB12403709', 'rank': 7},
#    {'isrc': 'USUG12404146', 'rank': 8},
#    {'isrc': 'USSM12403681', 'rank': 9},
#    {'isrc': 'QM24S2401097', 'rank': 10},
#    {'isrc': 'QM24S2401964', 'rank': 11},
#    {'isrc': 'QMGVJ2300156', 'rank': 12},
#    {'isrc': 'USAT22403723', 'rank': 13},
#    {'isrc': 'SGB502394921', 'rank': 14},
#    {'isrc': 'USCRB2400015', 'rank': 15},
#    {'isrc': 'USUG12404541', 'rank': 16},
#    {'isrc': 'CAUM72300663', 'rank': 17},
#    {'isrc': 'QZRD92404651', 'rank': 18},
#    {'isrc': 'USWB12400003', 'rank': 19},
#    {'isrc': 'USWB12307026', 'rank': 20},
#    {'isrc': 'QZ22S2300096', 'rank': 21},
#    {'isrc': 'USRN12400011', 'rank': 22},
#    {'isrc': 'USWB12400087', 'rank': 23},
#    {'isrc': 'USRN12300107', 'rank': 24},
#    {'isrc': 'USAT22406351', 'rank': 25},
#    {'isrc': 'QM6P42412668', 'rank': 26},
#    {'isrc': 'USWB12400281', 'rank': 27},
#    {'isrc': 'USUM72405595', 'rank': 28},
#    {'isrc': 'QMRSZ2401388', 'rank': 29},
#    {'isrc': 'US6XF2400148', 'rank': 30},
#    {'isrc': 'QZRD92405047', 'rank': 31},
#    {'isrc': 'USUG12406387', 'rank': 32},
#    {'isrc': 'USQX92401733', 'rank': 33},
#    {'isrc': 'QZZVQ2400059', 'rank': 34},
#    {'isrc': 'USUYG1541249', 'rank': 35},
#    {'isrc': 'USUG12309787', 'rank': 36},
#    {'isrc': 'QMCQK1900370', 'rank': 37},
#    {'isrc': 'USUG12403356', 'rank': 38},
#    {'isrc': 'USWB12402402', 'rank': 39},
#    {'isrc': 'USWB12404997', 'rank': 40},
#    {'isrc': 'USSM12401853', 'rank': 41},
#    {'isrc': 'QZTBF2448628', 'rank': 42},
#    {'isrc': 'QZYG82300092', 'rank': 43},
#    {'isrc': 'QMRSZ2400822', 'rank': 44},
#    {'isrc': 'USAT22408980', 'rank': 45},
#    {'isrc': 'QZRD92404862', 'rank': 46},
#    {'isrc': 'QZWH32400054', 'rank': 47},
#    {'isrc': 'USQX92403221', 'rank': 48},
#    {'isrc': 'USQX92404450', 'rank': 49},
#    {'isrc': 'QZZ222400014', 'rank': 50}]},
#  {'_id': ObjectId('673bd1cf7fc0f4ca6df0f08a'),
#   'key': 'Spotify_dance',
#   'value': [{'isrc': 'GBHAD2400076', 'rank': 1},
#    {'isrc': 'GBCFB2400830', 'rank': 2},
#    {'isrc': 'GBUM72405917', 'rank': 3},
#    {'isrc': 'DEEC33501671', 'rank': 4},
#    {'isrc': 'NLZ542400716', 'rank': 5},
#    {'isrc': 'USQX92404437', 'rank': 6},
#    {'isrc': 'GBCFB2401282', 'rank': 7},
#    {'isrc': 'GB45A2400212', 'rank': 8},
#    {'isrc': 'USA2P2446028', 'rank': 9},
#    {'isrc': 'GBCFB2400721', 'rank': 10},
#    {'isrc': 'SEBGA2401541', 'rank': 11},
#    {'isrc': 'US38Y2411868', 'rank': 12},
#    {'isrc': 'US38Y2424318', 'rank': 13},
#    {'isrc': 'QMDA62435301', 'rank': 14},
#    {'isrc': 'US38Y2417571', 'rank': 15},
#    {'isrc': 'GBCPZ2423810', 'rank': 16},
#    {'isrc': 'QMBZ92451076', 'rank': 17},
#    {'isrc': 'GBUM72406618', 'rank': 18},
#    {'isrc': 'USAT22408102', 'rank': 19},
#    {'isrc': 'USA2P2465995', 'rank': 20},
#    {'isrc': 'DEE862401009', 'rank': 21},
#    {'isrc': 'NL8RL2429546', 'rank': 22},
#    {'isrc': 'USRE12400414', 'rank': 23},
#    {'isrc': 'UKWLG2400072', 'rank': 24},
#    {'isrc': 'BEIW12400732', 'rank': 25},
#    {'isrc': 'GB5KW2402411', 'rank': 26},
#    {'isrc': 'US38Y2418589', 'rank': 27},
#    {'isrc': 'GBCFB2400964', 'rank': 28},
#    {'isrc': 'QZS7J2491002', 'rank': 29},
#    {'isrc': 'GBCFB2400907', 'rank': 30},
#    {'isrc': 'QMDA62467328', 'rank': 31},
#    {'isrc': 'USUG12405639', 'rank': 32},
#    {'isrc': 'GBCFB2400756', 'rank': 33},
#    {'isrc': 'USUG12406149', 'rank': 34},
#    {'isrc': 'US38Y2414974', 'rank': 35},
#    {'isrc': 'USUG12405837', 'rank': 36},
#    {'isrc': 'GBAHT2400508', 'rank': 37},
#    {'isrc': 'NLML62400170', 'rank': 38},
#    {'isrc': 'NLRD52339238', 'rank': 39},
#    {'isrc': 'US38Y2422094', 'rank': 40},
#    {'isrc': 'DEE862401827', 'rank': 41},
#    {'isrc': 'GBCPZ2423828', 'rank': 42},
#    {'isrc': 'GXD7V2245202', 'rank': 43},
#    {'isrc': 'USCRR2400003', 'rank': 44},
#    {'isrc': 'USRE12400467', 'rank': 45},
#    {'isrc': 'USA2P2446008', 'rank': 46},
#    {'isrc': 'DEA622403098', 'rank': 47},
#    {'isrc': 'USA2P2463486', 'rank': 48},
#    {'isrc': 'QM37X2400019', 'rank': 49},
#    {'isrc': 'SE4OX2400001', 'rank': 50},
#    {'isrc': 'DGA092443446', 'rank': 51},
#    {'isrc': 'QMDA62444746', 'rank': 52},
#    {'isrc': 'UK7MC2400052', 'rank': 53},
#    {'isrc': 'GBEWA2403591', 'rank': 54},
#    {'isrc': 'GBKQU2489166', 'rank': 55},
#    {'isrc': 'DED622400115', 'rank': 56},
#    {'isrc': 'USZ4V2400281', 'rank': 57},
#    {'isrc': 'GBUM72404368', 'rank': 58},
#    {'isrc': 'USUG12405928', 'rank': 59},
#    {'isrc': 'NL8RL2428855', 'rank': 60},
#    {'isrc': 'QM7282491512', 'rank': 61},
#    {'isrc': 'GBUM72403112', 'rank': 62},
#    {'isrc': 'DEKF22400981', 'rank': 63},
#    {'isrc': 'NLQ8D2400687', 'rank': 64},
#    {'isrc': 'GBJX32475025', 'rank': 65},
#    {'isrc': 'QM6P42476860', 'rank': 66},
#    {'isrc': 'GBAHT2400500', 'rank': 67},
#    {'isrc': 'CA6D22400322', 'rank': 68},
#    {'isrc': 'US38Y2419833', 'rank': 69},
#    {'isrc': 'QMBZ92421723', 'rank': 70},
#    {'isrc': 'US38Y2411971', 'rank': 71},
#    {'isrc': 'USNRS2443531', 'rank': 72},
#    {'isrc': 'GBBKS2400307', 'rank': 73},
#    {'isrc': 'USZXT2454685', 'rank': 74},
#    {'isrc': 'USZXT2455305', 'rank': 75}]},
#  {'_id': ObjectId('673bd1cf7fc0f4ca6df0f08b'),
#   'key': 'Spotify_pop',
#   'value': [{'isrc': 'USUM72404100', 'rank': 1},
#    {'isrc': 'USUM72409273', 'rank': 2},
#    {'isrc': 'USUG12406903', 'rank': 3},
#    {'isrc': 'USAT22409172', 'rank': 4},
#    {'isrc': 'USUM72401994', 'rank': 5},
#    {'isrc': 'USUG12401967', 'rank': 6},
#    {'isrc': 'USSM12405456', 'rank': 7},
#    {'isrc': 'USUG12406536', 'rank': 8},
#    {'isrc': 'USUM72404101', 'rank': 9},
#    {'isrc': 'USAT22406808', 'rank': 10},
#    {'isrc': 'USHM92438095', 'rank': 11},
#    {'isrc': 'USUM72401993', 'rank': 12},
#    {'isrc': 'USUYG1541249', 'rank': 13},
#    {'isrc': 'USUG12305911', 'rank': 14},
#    {'isrc': 'USUM72407015', 'rank': 15},
#    {'isrc': 'USRC12402958', 'rank': 16},
#    {'isrc': 'USRC12403001', 'rank': 17},
#    {'isrc': 'USUG12406387', 'rank': 18},
#    {'isrc': 'USUG12401766', 'rank': 19},
#    {'isrc': 'QM24S2402528', 'rank': 20},
#    {'isrc': 'USQX92405786', 'rank': 21},
#    {'isrc': 'DEEC33501508', 'rank': 22},
#    {'isrc': 'USUG12405846', 'rank': 23},
#    {'isrc': 'USWL12403266', 'rank': 24},
#    {'isrc': 'USUM72403305', 'rank': 25},
#    {'isrc': 'USQX92405226', 'rank': 26},
#    {'isrc': 'USAT22405399', 'rank': 27},
#    {'isrc': 'USUM72404990', 'rank': 28},
#    {'isrc': 'USSM12401865', 'rank': 29},
#    {'isrc': 'GBARL2400510', 'rank': 30},
#    {'isrc': 'USAT22307579', 'rank': 31},
#    {'isrc': 'QZ9QQ2400535', 'rank': 32},
#    {'isrc': 'QZTB92360479', 'rank': 33},
#    {'isrc': 'USUM72407248', 'rank': 34},
#    {'isrc': 'USUG12401040', 'rank': 35},
#    {'isrc': 'USWB12307016', 'rank': 36},
#    {'isrc': 'USUM72317276', 'rank': 37},
#    {'isrc': 'QM24S2400638', 'rank': 38},
#    {'isrc': 'USAT22401350', 'rank': 39},
#    {'isrc': 'USWB12302315', 'rank': 40},
#    {'isrc': 'USUG12407854', 'rank': 41},
#    {'isrc': 'GBKPL2205058', 'rank': 42},
#    {'isrc': 'USUG12401028', 'rank': 43},
#    {'isrc': 'USNPW2400899', 'rank': 44},
#    {'isrc': 'USUG12400968', 'rank': 45},
#    {'isrc': 'USUG12400910', 'rank': 46},
#    {'isrc': 'USWB12403464', 'rank': 47},
#    {'isrc': 'CA5KR2490788', 'rank': 48},
#    {'isrc': 'QZJ842400387', 'rank': 49},
#    {'isrc': 'USA2P2431062', 'rank': 50}]},
#  {'_id': ObjectId('673bd1cf7fc0f4ca6df0f08c'),
#   'key': 'Spotify_rap',
#   'value': [{'isrc': 'USUG12404786', 'rank': 1},
#    {'isrc': 'USQX92405790', 'rank': 2},
#    {'isrc': 'USUG12406536', 'rank': 3},
#    {'isrc': 'USSM12408345', 'rank': 4},
#    {'isrc': 'USAT22409580', 'rank': 5},
#    {'isrc': 'QZNMW2453746', 'rank': 6},
#    {'isrc': 'USSM12406730', 'rank': 7},
#    {'isrc': 'USSM12404181', 'rank': 8},
#    {'isrc': 'USRC12401455', 'rank': 9},
#    {'isrc': 'USAT22405399', 'rank': 10},
#    {'isrc': 'USUG12405324', 'rank': 11},
#    {'isrc': 'USUG12404790', 'rank': 12},
#    {'isrc': 'USQX92405793', 'rank': 13},
#    {'isrc': 'USUM72411015', 'rank': 14},
#    {'isrc': 'USWB12403878', 'rank': 15},
#    {'isrc': 'USSM12406727', 'rank': 16},
#    {'isrc': 'USUG12405322', 'rank': 17},
#    {'isrc': 'USAT22409327', 'rank': 18},
#    {'isrc': 'USA2P2466977', 'rank': 19},
#    {'isrc': 'USAT22409494', 'rank': 20},
#    {'isrc': 'USRC12403510', 'rank': 21},
#    {'isrc': 'USAT22404355', 'rank': 22},
#    {'isrc': 'USSM12406726', 'rank': 23},
#    {'isrc': 'USUM72410900', 'rank': 24},
#    {'isrc': 'USUG12405316', 'rank': 25},
#    {'isrc': 'USWB12401119', 'rank': 26},
#    {'isrc': 'USUM72410283', 'rank': 27},
#    {'isrc': 'TLVEM2467230', 'rank': 28},
#    {'isrc': 'USC4R2447758', 'rank': 29},
#    {'isrc': 'QZNMU2421699', 'rank': 30},
#    {'isrc': 'USRC12402085', 'rank': 31},
#    {'isrc': 'QZWFQ2421310', 'rank': 32},
#    {'isrc': 'USUG12404775', 'rank': 33},
#    {'isrc': 'QZNMW2453751', 'rank': 34},
#    {'isrc': 'USQX92405786', 'rank': 35},
#    {'isrc': 'USSM12408246', 'rank': 36},
#    {'isrc': 'USAT22408896', 'rank': 37},
#    {'isrc': 'USUM72410949', 'rank': 38},
#    {'isrc': 'USUG12407284', 'rank': 39},
#    {'isrc': 'USUM72410597', 'rank': 40},
#    {'isrc': 'USWB12402384', 'rank': 41},
#    {'isrc': 'USUM72410932', 'rank': 42},
#    {'isrc': 'USQX92405369', 'rank': 43},
#    {'isrc': 'USAT22409490', 'rank': 44},
#    {'isrc': 'USUG12405148', 'rank': 45},
#    {'isrc': 'USUM72409892', 'rank': 46},
#    {'isrc': 'USRC12103515', 'rank': 47},
#    {'isrc': 'USUM72411087', 'rank': 48},
#    {'isrc': 'USQX92404982', 'rank': 49},
#    {'isrc': 'USAT22409889', 'rank': 50}]}]
